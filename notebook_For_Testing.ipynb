# %%
import importlib
import PromptMaker_Model  # Your module
import prereq_checker  # Import the prereq_checker module

importlib.reload(PromptMaker_Model)
importlib.reload(prereq_checker)
#from PromptMaker_Model import check_prerequisites as check_prerequisites_model 
from prereq_checker import check_prerequisites as check_prerequisites
# Define test input
student_courses = [
    {
        "Quarter": "AUTUMN 2023 CSE",
        "Courses": [
            {
                "Course Code": "ENGL 121",
                "Course Name": "SPECIAL TOPICS",
                "Credits": "5.0",
                "Grade": "4.0"
            },
            {
                "Course Code": "PHYS 121",
                "Course Name": "MECHANICS",
                "Credits": "5.0",
                "Grade": "4.0"
            },
            {
                "Course Code": "CSE 121",
                "Course Name": "INTR CMP PRGR",
                "Credits": "4.0",
                "Grade": "4.0"
            },
            {
                "Course Code": "MATH 121",
                "Course Name": "CALCULUS ANLYT GEOM",
                "Credits": "5.0",
                "Grade": "4.0"
            }
        ]
    },
    {
        "Quarter": "WINTER 2024 CSE 8",
        "Courses": [
            {
                "Course Code": "MATH 208",
                "Course Name": "MTRX ALGB & APPL",
                "Credits": "3.0",
                "Grade": "WIP"
            },
            {
                "Course Code": "CSE 154",
                "Course Name": "WEB PRGRM",
                "Credits": "5.0",
                "Grade": "WIP"
            },
            {
                "Course Code": "CSE 311",
                "Course Name": "FONDRN COMPT",
                "Credits": "4.0",
                "Grade": "WIP"
            }
        ]
    },
    {
        "Quarter": "SPRING 2024 CSE 8",
        "Courses": [
            {
                "Course Code": "CSE 312",
                "Course Name": "FOUNDATIONS OF COMPUTING II",
                "Credits": "4.0",
                "Grade": "WIP"
            },
            {
                "Course Code": "CSE 332",
                "Course Name": "DATA STRUCTURES AND PARALLELISM",
                "Credits": "4.0",
                "Grade": "WIP"
            },
            {
                "Course Code": "CSE 351",
                "Course Name": "THE HARDWARE/SOFTWARE INTERFACE",
                "Credits": "4.0",
                "Grade": "WIP"
            }
        ]
    }
]
#Test Case 2: Student is missing some prerequisites
#✔ Expectation: The function should detect missing prerequisites.
student_courses_2 = [
    {
        "Quarter": "Autumn 2023",
        "Courses": [
            {
                "Course Code": "MATH 208",
                "Course Name": "Discrete Mathematics",
                "Credits": "4.0",
                "Grade": "3.7"
            }
        ]
    },
    {
        "Quarter": "Winter 2024",
        "Courses": [
            {
                "Course Code": "CSE 142",
                "Course Name": "Introduction to Programming",
                "Credits": "4.0",
                "Grade": "3.5"
            }
        ]
    }
]
response_text_2 = """Based on the job description, here are the recommended courses:

1. **CSE312 - Foundations of Computing II** (4 credits)
2. **CSE332 - Data Structures and Parallelism** (4 credits)
3. **CSE451 - Introduction to Operating Systems** (4 credits)
"""

#Test Case 3: Student meets either/or prerequisites
#✔ Expectation: The function should correctly handle "either/or" cases.


student_courses_3 = [
    {
        "Quarter": "Autumn 2023",
        "Courses": [
            {
                "Course Code": "CSE 311",
                "Course Name": "Foundations of Computing I",
                "Credits": "4.0",
                "Grade": "3.5"
            },
            {
                "Course Code": "MATH 208",
                "Course Name": "Linear Algebra",
                "Credits": "4.0",
                "Grade": "3.8"
            }
        ]
    },
    {
        "Quarter": "Winter 2024",
        "Courses": [
            {
                "Course Code": "CSE 332",
                "Course Name": "Software Design and Implementation",
                "Credits": "4.0",
                "Grade": "3.9"
            }
        ]
    }
]

response_text_3 = """Based on the job description, here are the recommended courses:

1. **CSE446 - Software Engineering** (4 credits)
"""
#Test Case 4: Student is missing a prerequisite with a minimum grade requirement
#✔ Expectation: The function should detect minimum grade violations

student_courses_3 = [
    {
        "Quarter": "Autumn 2023",
        "Courses": [
            {
                "Course Code": "CSE 311",
                "Course Name": "Foundations of Computing I",
                "Credits": "4.0",
                "Grade": "3.5"
            },
            {
                "Course Code": "MATH 208",
                "Course Name": "Linear Algebra",
                "Credits": "4.0",
                "Grade": "3.8"
            }
            
        ]
    },
    {
        "Quarter": "Winter 2024",
        "Courses": [
            {
                "Course Code": "CSE 332",
                "Course Name": "Software Design and Implementation",
                "Credits": "4.0",
                "Grade": "3.9"
            }
        ]
    }
]

response_text_3 = """Based on the job description, here are the recommended courses:

1. **CSE446 - Software Engineering** (4 credits)
2. **CSE452 - Introduction to Distributed SystemsCoursePrerequisite:¬†CSE 332 and CSE 333.
"""
#Test Case 4: Student is missing a prerequisite with a minimum grade requirement
#✔ Expectation: The function should detect minimum grade violations


student_courses_4 = [
    {
        "Quarter": "Autumn 2023",
        "Courses": [
            {
                "Course Code": "CSE 311",
                "Course Name": "Foundations of Computing I",
                "Credits": "4.0",
                "Grade": "2.5"  # Below minimum required grade
            }
        ]
    },
    {
        "Quarter": "Winter 2024",
        "Courses": [
            {
                "Course Code": "STAT 390",
                "Course Name": "Probability and Statistics",
                "Credits": "4.0",
                "Grade": "3.5"
            }
        ]
    }
]
response_text_4 = """Based on the job description, here are the recommended courses:

1. **CSE312 - Foundations of Computing II** (4 credits)
2. **CSE344 - Introduction to Data Management** (4 credits)
"""

response_text = """Based on the job description, here are the recommended courses:

1. **CSE412 - Introduction to Data Visualization** (4 credits)
2. **CSE414 -Introduction to Database Systems ** (4 credits)
3. **CSE452 - Introduction to Artificial IntelligenceCoursePrerequisite:¬†CSE 373.** (4 credits)
"""
#test case 5 - student is miss one orereq and hasn't taken an optinal prereq
student_courses_5 = [
    {
        "Quarter": "Autumn 2023",
        "Courses": [
            {
                "Course Code": "CSE 311",
                "Course Name": "Foundations of Computing I",
                "Credits": "4.0",
                "Grade": "3.5"
            },
            {
                "Course Code": "MATH 208",
                "Course Name": "Linear Algebra",
                "Credits": "4.0",
                "Grade": "3.8"
            }
            
        ]
    },
    {
        "Quarter": "Winter 2024",
        "Courses": [
            {
                "Course Code": "CSE 332",
                "Course Name": "Software Design and Implementation",
                "Credits": "4.0",
                "Grade": "3.9"
            }
        ]
    }
]

response_text_5 = """Based on the job description, here are the recommended courses:

1. **CSE446 - Software Engineering** (4 credits)
2. **CSE452 - Introduction to Distributed SystemsCoursePrerequisite:¬†CSE 332 and CSE 333.
"""

# Run function
missing_prereqs = check_prerequisites(response_text_5, student_courses_5, "course_database.db")

# Display result
print("Missing Prerequisites:", missing_prereqs)
# Out:
# Missing Prerequisites:
# Before taking some of the recommended courses, consider completing these prerequisites:
# CSE446:
#   Mandatory Prerequisites: CSE 312 or STAT 390 or STAT 391
#   Optional Prerequisites: None
# CSE452:
#   Mandatory Prerequisites: CSE 333
#   Optional Prerequisites: CSE 451
